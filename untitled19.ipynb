# %% [markdown]
# <a href="https://colab.research.google.com/github/parthasarathisaha18/C/blob/main/untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name ="Partha"
age=22
print (name)
# Out:
# Partha

# %%
name ="Partha"
age=22
print (name)
is_adult= True
print (is_adult)
# Out:
# Partha
# True

# %%
Name ="Tony Stark"
age = 51
is_genius = True
print (Name)
print (age)
print (is_genius)
# Out:
# Tony Stark
# 51
# True

# %%
name = input("What Is your name?" )
print(name)
# Out:
# What Is your name?pss
# pss

# %%
name= input ("What is your super hero name Tony?" )
print (name )
# Out:
# What is your super hero name Tony?ironman
# ironman

# %%
old_age=input("Enter your age" )
new_age=int(old_age) + 2
print(new_age)
# Out:
# Enter your age20
# 22

# %%
num= 18
print(float(num))
# Out:
# 18.0

# %%
first_num = input("enter first number")
second_num = input("enter second number")
sum = int(first_num) + int(second_num)
print(sum)
# Out:
# enter first number78
# enter second number98
# 176

# %%
name = "Tony  Stark"
print(name.upper())
# Out:
# TONY  STARK

# %%
print(name.find("S"))
# Out:
# 6

# %%
print(name.replace("Tony", "Ironman"))
# Out:
# Ironman  Stark

# %%
print('Ton' in name)
# Out:
# True

# %%
print (5 + 2)
# Out:
# 7

# %%
print (5//2)
# Out:
# 2

# %%
print(17%6)
# Out:
# 5

# %%
print (5**2)
# Out:
# 25

# %%
i =5
i +=2
print(i)
# Out:
# 7

# %%
print ( 2 + 3 *5 )
# Out:
# 17

# %%
#kllhlh

# %%
print(17>8)
# Out:
# True

# %%
print(3==2)
# Out:
# False

# %%
print (3!=2)
# Out:
# True

# %%
print (2 >3 or 6>5)
# Out:
# True

# %%
print (2 >3 and 6>5)
# Out:
# False

# %%
print (not 2 >3 and 6>5)
# Out:
# True

# %%
age =

# %%
n = input("Enter your number")
n = int(n) # Convert input to integer
if (n % 2 != 0):
   print("Weird")
elif ( n %2 == 0 and 2<=n<=5)  :
    print("Not Weird")
elif ( n%2 == 0 and 6<=n<=20)  :
    print("Weird")
elif(n%2==0 and n>20):
    print("Not Weird")
# Out:
# Enter your number23
# Weird

# %%
#build a calculator
a =input("enter your Num" )
b=input("enter your Num" )
a=int(a)
b=int(b)
print(a+b)
print(a - b)
print(a * b)
print(a / b)
print (a % b)
# Out:
# enter your Num5
# enter your Num9
# 14
# -4
# 45
# 0.5555555555555556
# 5

# %%
#build a calculator
a =input("enter your Num" )
b=input("enter your Num" )
a=int(a)
b=int(b)
operator=input("enter your operator" )
if (operator == '+'):
    print(a+b)
elif (operator == '-'):
    print(a-b)
elif (operator == '*'):
    print(a*b)
elif (operator == '/'):
    print(a/b)
elif (operator == '%'):
    print(a%b)
else:
    print("invalid operator")
# Out:
# enter your Num44
# enter your Num333
# enter your operator*
# 14652

# %%
a = input("Enter your num " )
b = input("Enter your num " )
a = int(a)
b = int(b)
operator = input("Enter your operator " )
if operator =='+':
  print (a + b)
elif operator == '-':
  print (a - b)
elif operator =='*':
  print (a * b)
elif operator =='/':
  print (a / b)
elif operator =='%':
  print (a % b)
else:
    print("invalid Operator")
# Out:
# Enter your num 15
# Enter your num 9
# Enter your operator %
# 6

# %%
numbers = range (5)
print (numbers)
# Out:
# range(0, 5)

# %%
i = 1
while i <= 5:
  print(i * "*")
  i +=1
# Out:
# *
# **
# ***
# ****
# *****

# %%
 i= 5
while i >= 0:
  print(i * "*")
  i -=1
# Out:
# *****
# ****
# ***
# **
# *

# %%
for i in range(5):
  print (i * '*')
# Out:
# *
# **
# ***
# ****

# %%
#list
marks=[95,98,90]
print(marks[1])
print(marks[1:2])
# Out:
# 98
# [98]
